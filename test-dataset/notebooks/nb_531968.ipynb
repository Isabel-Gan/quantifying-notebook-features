# %%
import sys
sys.path.append('../')

# %%
import ctn_benchmark

# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from hyperopt import fmin, hp, tpe, Trials, rand
import pickle
import hyperopt

# %%
import wm_benchmark_00
reload(wm_benchmark_00)
# Out:
# <module 'wm_benchmark_00' from '../wm_benchmark_00.pyc'>

# %%
def objective(x):
    vals = wm_benchmark_00.Working_Memory().run(
        #input_scale = x['input_scale'],
        intercept_low = x['intercept_low'],
        intercept_high = x['intercept_high'],
        #tau_input = x['tau_input'],
        #tau_recurrent = x['tau_recurrent'],
        #tau_reset = x['tau_reset'],
        #max_rate_high = x['max_rate_high'],
        #max_rate_low = x['max_rate_low']
    )
    return{
        'loss':
            abs(vals['act_510'] - 28) + abs(vals['act_1750'] - 33) + abs(vals['peak'] - 53),
        'status':hyperopt.STATUS_OK,
    }
trials = Trials()
best = fmin(objective,
           space = {#'input_scale':hp.uniform('input_scale', 0.1, 10),
                    'intercept_low':hp.uniform('intercept_low', -0.5, 0.5),
                    'intercept_high':hp.uniform('intercept_high', 0.5, 1.0),
                    #'tau_input':hp.uniform('tau_input', 0.002, 0.2),
                    #'tau_recurrent':hp.uniform('tau_recurrent', 0.002, 0.2),
                    #'tau_reset':hp.uniform('tau_reset', 0.002, 0.2),
                    #'max_rate_high':hp.uniform('max_rate_high', 150, 250),
                    #'max_rate_low':hp.uniform('max_rate_low', 100, 150)
                   },
           algo = hyperopt.rand.suggest,
           max_evals = 200,
           trials = trials
           )
pickle.dump({'Trials':trials, 'Best':best}, open('wm_data_intercepts', 'w'))
# Out:
# running Working_Memory#20160809-101401-04f53ba5
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.19646918559786164
# _intercept_high = 0.6430696674751897
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 2.2340121905731347e-09
# act_510 = 0.0
# peak = 0.39873163615332269
# running Working_Memory#20160809-101403-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.3939350940452673
# _intercept_high = 0.8727357424428065
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 27.580616231970581
# act_510 = 13.758430298184459
# peak = 33.380705905350787
# running Working_Memory#20160809-101406-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.006726011499569973
# _intercept_high = 0.5287653475840448
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.023502520795483411
# act_510 = 0.0
# peak = 16.767627095029951
# running Working_Memory#20160809-101408-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.3948278727823248
# _intercept_high = 0.5640720360170002
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.23615495866197
# act_510 = 20.0642158336995
# peak = 46.974050405772878
# running Working_Memory#20160809-101412-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.023833319954675858
# _intercept_high = 0.519981487074987
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 6.2265500211530672e-05
# act_510 = 0.0
# peak = 14.424590151487607
# running Working_Memory#20160809-101414-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.3666370428503979
# _intercept_high = 0.6315724247987069
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101416-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.07053162514540678
# _intercept_high = 0.6341298879069505
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 5.8808073211758686e-08
# act_510 = 0.0
# peak = 5.6495512692386534
# running Working_Memory#20160809-101419-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.3583697309232593
# _intercept_high = 0.655772180563795
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 35.239701605993986
# act_510 = 15.149749970191376
# peak = 39.741676231090118
# running Working_Memory#20160809-101422-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.15015360547174905
# _intercept_high = 0.9740545829201349
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 4.1326019559048852e-09
# act_510 = 0.0
# peak = 0.65982485637327504
# running Working_Memory#20160809-101424-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.28090389879246613
# _intercept_high = 0.6905722709096708
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 6.3880976171343832e-10
# act_510 = 0.0
# peak = 0.11401623614836531
# running Working_Memory#20160809-101426-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.08049138365129438
# _intercept_high = 0.5648304296423854
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 12.790632873846199
# act_510 = 1.573405337387076
# peak = 20.221085197601607
# running Working_Memory#20160809-101429-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.31140362630858487
# _intercept_high = 0.7238821224235725
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 6.9575660929014036e-10
# act_510 = 0.0
# peak = 0.12418024053645538
# running Working_Memory#20160809-101431-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.16132894244996465
# _intercept_high = 0.6638473501503275
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 3.7000128013002684e-09
# act_510 = 0.0
# peak = 0.66038679836935221
# running Working_Memory#20160809-101433-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.3467840631002034
# _intercept_high = 0.5740839142320807
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 37.011974496759876
# act_510 = 15.917922361396862
# peak = 42.583862796900014
# running Working_Memory#20160809-101436-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.4438502081196458
# _intercept_high = 0.5442720140817424
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101438-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.24934226131868875
# _intercept_high = 0.8526150557569572
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 8.2002936417541919e-10
# act_510 = 0.0
# peak = 0.14636072777541534
# running Working_Memory#20160809-101440-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.009037612476234691
# _intercept_high = 0.8766224204005195
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.65217020832932748
# act_510 = 0.12166344970775422
# peak = 7.8445337288348798
# running Working_Memory#20160809-101442-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.24790551649635373
# _intercept_high = 0.5543661599504511
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 9.3052260863707152e-10
# act_510 = 0.0
# peak = 0.16608181628781954
# running Working_Memory#20160809-101444-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.4173854839516489
# _intercept_high = 0.7611974488178093
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101446-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.40206152481250823
# _intercept_high = 0.7789037678930524
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101448-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.23775496165064092
# _intercept_high = 0.6699773703365612
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 7.7273446531426775e-10
# act_510 = 0.0
# peak = 0.13791942540285568
# running Working_Memory#20160809-101450-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.40665594201999267
# _intercept_high = 0.9454715067240393
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 24.383136525975548
# act_510 = 13.396736280871885
# peak = 31.683194234234517
# running Working_Memory#20160809-101454-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.21695805233345666
# _intercept_high = 0.5010148997930048
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 30.797481791173116
# act_510 = 8.4195421903833516
# peak = 34.359555447075728
# running Working_Memory#20160809-101457-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.001890564754342683
# _intercept_high = 0.8094534826131692
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.33976875177133031
# act_510 = 0.11567962262874339
# peak = 8.8928251373674403
# running Working_Memory#20160809-101459-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.13330443060222363
# _intercept_high = 0.8164906834745822
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 12.068042083519757
# act_510 = 2.402672977701731
# peak = 16.091436303016025
# running Working_Memory#20160809-101502-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.07540585223123486
# _intercept_high = 0.5701542036262912
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 5.0048528836275929e-08
# act_510 = 0.0
# peak = 6.2654225238311456
# running Working_Memory#20160809-101505-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.38130755097666214
# _intercept_high = 0.9898518016589579
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101507-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.40858393856745034
# _intercept_high = 0.6289858206376238
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101508-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.2697943163974402
# _intercept_high = 0.5884108505494121
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 8.3584870948052376e-10
# act_510 = 0.0
# peak = 0.1491842009252016
# running Working_Memory#20160809-101510-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.44872777388844687
# _intercept_high = 0.8718219264053846
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101512-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.3523001470797744
# _intercept_high = 0.7645922011254351
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 29.98871929337081
# act_510 = 12.722153097980234
# peak = 33.99028446121104
# running Working_Memory#20160809-101516-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.007723768367261297
# _intercept_high = 0.8152753036724132
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.009097840201903757
# act_510 = 0.0
# peak = 8.4660118253386702
# running Working_Memory#20160809-101518-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.1523263257973545
# _intercept_high = 0.9605614824323113
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 3.4524519625655446e-09
# act_510 = 0.0
# peak = 0.61620157024359956
# running Working_Memory#20160809-101520-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.18638049139706203
# _intercept_high = 0.7795001768290102
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 18.034724426048435
# act_510 = 4.4257049161104653
# peak = 21.810894044296802
# running Working_Memory#20160809-101523-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.2974020646840758
# _intercept_high = 0.7926102861534241
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 7.7612417854260714e-10
# act_510 = 0.0
# peak = 0.13852442921945496
# running Working_Memory#20160809-101524-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4037306591698423
# _intercept_high = 0.5775033674778711
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 41.497317269314678
# act_510 = 19.934368564789203
# peak = 47.130425883649217
# running Working_Memory#20160809-101528-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.2888463751831797
# _intercept_high = 0.5981960566656694
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 7.1512988070477719e-10
# act_510 = 0.0
# peak = 0.12763802659572435
# running Working_Memory#20160809-101530-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.33339282480074517
# _intercept_high = 0.6617172874517311
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 5.082569712642522e-10
# act_510 = 0.0
# peak = 0.090714873711828792
# running Working_Memory#20160809-101532-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.4406736056841625
# _intercept_high = 0.6756041087605681
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101534-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.17899991749074518
# _intercept_high = 0.8778775904913136
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 13.584112097969617
# act_510 = 3.8076458266484909
# peak = 17.619565145093574
# running Working_Memory#20160809-101537-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.18896385486065292
# _intercept_high = 0.7370448305316755
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 2.4876194590597047e-09
# act_510 = 0.0
# peak = 0.44399604497379697
# running Working_Memory#20160809-101539-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.14301726824994399
# _intercept_high = 0.6533511656800641
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 18.39292239382242
# act_510 = 3.5246785086551733
# peak = 22.210200814433897
# running Working_Memory#20160809-101542-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.326222888961089
# _intercept_high = 0.8079501019703218
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 3.7638795746308529e-10
# act_510 = 0.0
# peak = 0.067178588702849013
# running Working_Memory#20160809-101544-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.20226096979018804
# _intercept_high = 0.9136385408277148
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 15.878057087350797
# act_510 = 4.2667039336646528
# peak = 18.094455401506359
# running Working_Memory#20160809-101546-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.3983790484749181
# _intercept_high = 0.5825577494132091
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101548-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.09779875049432929
# _intercept_high = 0.760423098033572
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 1.213229834497577e-08
# act_510 = 0.0
# peak = 1.9799182334110077
# running Working_Memory#20160809-101551-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.1695907794784146
# _intercept_high = 0.953787325815237
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 2.3963336226328933e-09
# act_510 = 0.0
# peak = 0.42770313884298927
# running Working_Memory#20160809-101553-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.44735458240220183
# _intercept_high = 0.6134308912923792
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 41.309281036522272
# act_510 = 22.157456753854351
# peak = 48.646160650685964
# running Working_Memory#20160809-101556-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.15774617842016392
# _intercept_high = 0.9422382134516142
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 3.3206913962013348e-09
# act_510 = 0.0
# peak = 0.51491319150107007
# running Working_Memory#20160809-101558-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.35059815554390705
# _intercept_high = 0.5623040596106924
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 38.426721361018345
# act_510 = 17.083692841071464
# peak = 43.318204506795979
# running Working_Memory#20160809-101602-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.40674252044744197
# _intercept_high = 0.8546075166585563
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 29.614979260084851
# act_510 = 14.540273650203879
# peak = 35.095183066171884
# running Working_Memory#20160809-101605-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.03996126631200814
# _intercept_high = 0.9481577385311202
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 1.3927481594043849
# act_510 = 0.55984531617230937
# peak = 7.4624652126563218
# running Working_Memory#20160809-101607-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.30208784653077025
# _intercept_high = 0.6330073611914953
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 5.5472390398043584e-10
# act_510 = 0.0
# peak = 0.099008398781715259
# running Working_Memory#20160809-101609-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.1425621886950903
# _intercept_high = 0.6063024689649346
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 20.037189316034997
# act_510 = 3.9546092507437529
# peak = 24.140259294318916
# running Working_Memory#20160809-101612-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.0028311147323426544
# _intercept_high = 0.8929021588440871
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.12784908312026186
# act_510 = 0.0
# peak = 7.7739071893983063
# running Working_Memory#20160809-101615-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.02459625266055221
# _intercept_high = 0.5191800007229515
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 2.0028315595009695e-05
# act_510 = 0.0
# peak = 14.565883554658699
# running Working_Memory#20160809-101618-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.4504550464921385
# _intercept_high = 0.6452636732889399
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101620-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.06272309989856728
# _intercept_high = 0.547631383078242
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 9.6331799593542844e-08
# act_510 = 0.0
# peak = 8.1543739877470589
# running Working_Memory#20160809-101622-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.024023109374771034
# _intercept_high = 0.5570447814024801
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 1.8989566679509023e-05
# act_510 = 0.0
# peak = 12.807923424476703
# running Working_Memory#20160809-101625-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.37656719570022124
# _intercept_high = 0.5314317334104153
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101627-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.3233533628598092
# _intercept_high = 0.9463111619157315
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 6.126171570038487e-10
# act_510 = 0.0
# peak = 0.10934131979157852
# running Working_Memory#20160809-101629-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4315439666284242
# _intercept_high = 0.7526409337226064
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 36.297995444986618
# act_510 = 18.080228418255839
# peak = 40.559477707355427
# running Working_Memory#20160809-101632-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.36944645066191695
# _intercept_high = 0.7575237260175509
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 32.264455536067686
# act_510 = 14.078248836281501
# peak = 35.675133259446966
# running Working_Memory#20160809-101635-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.04269865938231254
# _intercept_high = 0.837741118672064
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 3.5910006059969868e-07
# act_510 = 0.0
# peak = 4.8263590193259196
# running Working_Memory#20160809-101637-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.07995900831905578
# _intercept_high = 0.774951870815114
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 4.2688337417783098
# act_510 = 1.4676811335550759
# peak = 12.751988894713145
# running Working_Memory#20160809-101640-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.011977617473078794
# _intercept_high = 0.8948449874221378
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0019154519379656668
# act_510 = 0.0
# peak = 6.6884287462211152
# running Working_Memory#20160809-101642-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.07729076425188752
# _intercept_high = 0.6889492483518357
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 8.7705763994770045
# act_510 = 1.3657611671010097
# peak = 15.167358285189067
# running Working_Memory#20160809-101645-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.24512781747195134
# _intercept_high = 0.8135934245444278
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 7.8595150468218743e-10
# act_510 = 0.0
# peak = 0.14027843300116263
# running Working_Memory#20160809-101647-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.04160974819907892
# _intercept_high = 0.6277544631370697
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 5.350745955737396e-07
# act_510 = 0.0
# peak = 8.4567646518555009
# running Working_Memory#20160809-101649-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.2572996847916257
# _intercept_high = 0.6829708646126635
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 1.0445046397940526e-09
# act_510 = 0.0
# peak = 0.1864255914771768
# running Working_Memory#20160809-101652-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.0980113201985956
# _intercept_high = 0.831568536646974
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 6.4261476788839849
# act_510 = 1.8712381483521261
# peak = 12.812859038296379
# running Working_Memory#20160809-101654-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.4676985100563591
# _intercept_high = 0.8592683852818428
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101656-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.3873276617361001
# _intercept_high = 0.5490857517675477
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101658-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.1895092754954112
# _intercept_high = 0.7889876954023203
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 2.7577778298868041e-09
# act_510 = 0.0
# peak = 0.49221453262348597
# running Working_Memory#20160809-101700-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.367906754173434
# _intercept_high = 0.8923514437485629
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-101701-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.10980158786341765
# _intercept_high = 0.9794550061598148
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 7.8876975603519631e-09
# act_510 = 0.0
# peak = 1.2522404008933021
# running Working_Memory#20160809-101704-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.15479169463414577
# _intercept_high = 0.9910196423847548
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 3.1101371540762403e-09
# act_510 = 0.0
# ...
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-102123-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.1876991858385042
# _intercept_high = 0.7856619171512322
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 2.4913133048869963e-09
# act_510 = 0.0
# peak = 0.44465533107645444
# running Working_Memory#20160809-102126-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.200445005138994
# _intercept_high = 0.7107412881111056
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 21.428426466890532
# act_510 = 5.724132430077038
# peak = 25.04366520191325
# running Working_Memory#20160809-102130-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.04887743129994526
# _intercept_high = 0.6105111708567728
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 2.8652132520577935
# act_510 = 0.89810633232445869
# peak = 15.267225319488558
# running Working_Memory#20160809-102134-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.16272000138775178
# _intercept_high = 0.7967887417897699
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 14.704581281146783
# act_510 = 3.5110347007700464
# peak = 18.219226123239796
# running Working_Memory#20160809-102138-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.136281212155408
# _intercept_high = 0.912521170573782
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 5.0032791991136659e-09
# act_510 = 0.0
# peak = 0.80874797814465682
# running Working_Memory#20160809-102140-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.2501484234273287
# _intercept_high = 0.6405175356652314
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 9.3796280976496391e-10
# act_510 = 0.0
# peak = 0.16740976050475517
# running Working_Memory#20160809-102142-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.08326738567939984
# _intercept_high = 0.9148167472249398
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 3.1973960946667241
# act_510 = 1.2158374999579351
# peak = 9.9977722694274167
# running Working_Memory#20160809-102144-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.34483351217822844
# _intercept_high = 0.9246484896163614
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 23.652079661941233
# act_510 = 10.498184829110984
# peak = 28.283356544844775
# running Working_Memory#20160809-102147-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.20991546058358923
# _intercept_high = 0.9774967754372503
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 14.285614116251818
# act_510 = 4.0861127096144276
# peak = 17.292160651143085
# running Working_Memory#20160809-102149-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.17936900529775346
# _intercept_high = 0.709309209879091
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 18.718788654858795
# act_510 = 4.9337338786634444
# peak = 22.912333523469869
# running Working_Memory#20160809-102152-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.2844629110165905
# _intercept_high = 0.8444313864298834
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 9.7013259658961503e-10
# act_510 = 0.0
# peak = 0.17315149807871438
# running Working_Memory#20160809-102153-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.28795192812523185
# _intercept_high = 0.9057532414658498
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 6.7320199047866314e-10
# act_510 = 0.0
# peak = 0.12015464027363541
# running Working_Memory#20160809-102155-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.31851935110299856
# _intercept_high = 0.8342843020358284
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 5.3695029647204282e-10
# act_510 = 0.0
# peak = 0.095836124417200602
# running Working_Memory#20160809-102157-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.045460723127315306
# _intercept_high = 0.7197519644067052
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 1.7274467238130966
# act_510 = 0.9720457931223605
# peak = 12.28944251151894
# running Working_Memory#20160809-102159-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.28327312066009025
# _intercept_high = 0.7093610099326325
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 25.769651034330021
# act_510 = 9.5718225457201189
# peak = 30.707534070884794
# running Working_Memory#20160809-102203-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.3344603757164919
# _intercept_high = 0.775052183011053
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 26.474535071222615
# act_510 = 11.532101246656801
# peak = 32.144046598199608
# running Working_Memory#20160809-102206-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.4168735814929675
# _intercept_high = 0.794270956820961
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-102208-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.11667915788603367
# _intercept_high = 0.6395827260776199
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 1.1629417400765845e-08
# act_510 = 0.0
# peak = 1.8825932094761617
# running Working_Memory#20160809-102210-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.3305704137618988
# _intercept_high = 0.8727321126391501
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 5.2194232596794822e-10
# act_510 = 0.0
# peak = 0.093157467308841724
# running Working_Memory#20160809-102211-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.19564968600266341
# _intercept_high = 0.8631510871545454
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 17.230877474547135
# act_510 = 4.2659303624384313
# peak = 19.497168671873805
# running Working_Memory#20160809-102214-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.08672819358589545
# _intercept_high = 0.6700882423566692
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 1.9669847370101478e-08
# act_510 = 0.0
# peak = 3.2147447543893648
# running Working_Memory#20160809-102216-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.49844450556318287
# _intercept_high = 0.9577896438191882
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-102217-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.2143539854148292
# _intercept_high = 0.6279833023347172
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 1.072761168124505e-09
# act_510 = 0.0
# peak = 0.19146888167082765
# running Working_Memory#20160809-102219-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = 0.3859479412560747
# _intercept_high = 0.5389561793580622
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 0.0
# act_510 = 0.0
# peak = 0.0
# running Working_Memory#20160809-102221-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.087425605849205
# _intercept_high = 0.5708460314733801
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 14.132077575569205
# act_510 = 1.6986015822270779
# peak = 20.747359421663266

# %%
print(best)
# Out:
# {'intercept_high': 0.6380836644234733, 'intercept_low': -0.4865065952891877}

# %%
import pandas
import seaborn as sns
data = ctn_benchmark.Data('data')
df = pandas.DataFrame(data.data)
df = df[df._tau_input == 0.009683186948674292]
df = df[df._input_scale == 0.38314316705290097]
df = df[df._max_rate_high == 225.01822297425895]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = '_intercept_low'
sns.regplot(x, y = 'act_510', ax = ax1, data = df)
sns.regplot(x, y = 'act_1750', ax = ax2, data = df)
sns.regplot(x, y = 'peak', ax = ax3, data = df)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = '_intercept_high'
sns.regplot(x, y = 'act_510', ax = ax1, data = df)
sns.regplot(x, y = 'act_1750', ax = ax2, data = df)
sns.regplot(x, y = 'peak', ax = ax3, data = df)

# %%
df['intercept_range'] = df['_intercept_high']-df['_intercept_low']
fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = 'intercept_range'
sns.regplot(x, y = 'peak', ax = ax1, data = df)
sns.regplot(x, y = 'act_510', ax = ax2, data = df)
sns.regplot(x, y = 'act_1750', ax = ax3, data = df)

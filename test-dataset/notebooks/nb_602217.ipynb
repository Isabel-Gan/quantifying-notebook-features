# %%
import sys
sys.path.append('../')

# %%
import ctn_benchmark

# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from hyperopt import fmin, hp, tpe, Trials, rand
import pickle
import hyperopt

# %%
import wm_benchmark_00
reload(wm_benchmark_00)
# Out:
# <module 'wm_benchmark_00' from '../wm_benchmark_00.pyc'>

# %%
def objective(x):
    vals = wm_benchmark_00.Working_Memory().run(
        #input_scale = x['input_scale'],
        #intercept_low = x['intercept_low'],
        #intercept_high = x['intercept_high'],
        #tau_input = x['tau_input'],
        #tau_recurrent = x['tau_recurrent'],
        #tau_reset = x['tau_reset'],
        max_rate_high = x['max_rate_high'],
        max_rate_low = x['max_rate_low']
    )
    return{
        'loss':
            abs(vals['act_510'] - 28) + abs(vals['act_1750'] - 33) + abs(vals['peak'] - 53),
        'status':hyperopt.STATUS_OK,
    }
trials = Trials()
best = fmin(objective,
           space = {#'input_scale':hp.uniform('input_scale', 0.1, 10),
                    #'intercept_low':hp.uniform('intercept_low', -0.5, 0.5),
                    #'intercept_high':hp.uniform('intercept_high', 0.5, 1.0),
                    #'tau_input':hp.uniform('tau_input', 0.002, 0.2),
                    #'tau_recurrent':hp.uniform('tau_recurrent', 0.002, 0.2),
                    #'tau_reset':hp.uniform('tau_reset', 0.002, 0.2),
                    'max_rate_high':hp.uniform('max_rate_high', 150, 250),
                    'max_rate_low':hp.uniform('max_rate_low', 100, 150)
                   },
           algo = hyperopt.tpe.suggest,
           max_evals = 200,
           trials = trials
           )
pickle.dump({'Trials':trials, 'Best':best}, open('wm_data_max_rates', 'w'))
# Out:
# running Working_Memory#20160809-101416-7ebb415a
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 178.61393349503794
# _max_rate_low = 134.8234592798931
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 37.519386026373326
# act_510 = 21.75860323118383
# peak = 44.77764495511984
# running Working_Memory#20160809-101420-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 224.5471484885613
# _max_rate_low = 105.30324529773664
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 40.614327448775292
# act_510 = 23.46834904578024
# peak = 48.206757539623368
# running Working_Memory#20160809-101424-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 155.75306951680898
# _max_rate_low = 125.3363005749785
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 33.3215635070476
# act_510 = 19.692948366381088
# peak = 40.365205022241604
# running Working_Memory#20160809-101427-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 162.81440720340004
# _max_rate_low = 105.25860636088376
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 31.75542429863183
# act_510 = 19.134043451476803
# peak = 39.028367389050395
# running Working_Memory#20160809-101431-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 153.99629741499743
# _max_rate_low = 126.19166599773379
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 34.018097949101865
# act_510 = 19.828693898407042
# peak = 40.140934147212306
# running Working_Memory#20160809-101435-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 176.31448495974138
# _max_rate_low = 143.3318521425199
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 38.157283183021853
# act_510 = 22.815203982488779
# peak = 45.412789071781248
# running Working_Memory#20160809-101439-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 176.82597758139008
# _max_rate_low = 128.52658125727035
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 36.837180682759865
# act_510 = 21.391151592778616
# peak = 43.391981466340837
# running Working_Memory#20160809-101443-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 181.154436112759
# _max_rate_low = 107.08151345383703
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 34.722883613900763
# act_510 = 20.381770842355355
# peak = 41.741443996058493
# running Working_Memory#20160809-101447-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 244.81091658402698
# _max_rate_low = 132.50768027358745
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 47.245930173418465
# act_510 = 26.224871510922945
# peak = 54.970403574980118
# running Working_Memory#20160809-101450-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 188.11445418193415
# _max_rate_low = 139.04519493962331
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 39.656311276588347
# act_510 = 23.040073579715543
# peak = 46.875932780071516
# running Working_Memory#20160809-101454-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 162.96608592847707
# _max_rate_low = 120.97543081743528
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 33.695486213329481
# act_510 = 20.010560623847127
# peak = 40.536987434465573
# running Working_Memory#20160809-101458-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 194.7764244847145
# _max_rate_low = 140.57018131542924
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 40.855454637843799
# act_510 = 23.074726148036401
# peak = 48.44118303828499
# running Working_Memory#20160809-101502-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 182.7694700300655
# _max_rate_low = 133.06644712249823
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 37.948716197580062
# act_510 = 21.472104267590392
# peak = 45.556141462327936
# running Working_Memory#20160809-101506-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 164.81678284641615
# _max_rate_low = 107.66079684498983
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 32.680456131901849
# act_510 = 19.152215725606421
# peak = 38.922313775980442
# running Working_Memory#20160809-101509-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 158.85440281634848
# _max_rate_low = 147.1925104059823
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 36.211532843944532
# act_510 = 21.969306371222292
# peak = 43.393155504609162
# running Working_Memory#20160809-101513-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 220.52301115139144
# _max_rate_low = 137.46711306593443
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.096927111351683
# act_510 = 25.075435588778738
# peak = 51.666513051561907
# running Working_Memory#20160809-101517-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 225.3244840801039
# _max_rate_low = 124.54811937618827
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.675352111381251
# act_510 = 24.446967264745904
# peak = 50.330501835617952
# running Working_Memory#20160809-101520-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 160.87323199009023
# _max_rate_low = 137.3952758248177
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 35.020683670090826
# act_510 = 20.573525430867438
# peak = 42.42793882453541
# running Working_Memory#20160809-101525-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 202.23948976356186
# _max_rate_low = 145.86927419758246
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.099614119575911
# act_510 = 24.369625229503264
# peak = 49.420873317923927
# running Working_Memory#20160809-101529-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 205.78075357861047
# _max_rate_low = 145.1030762406254
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.843715512567321
# act_510 = 24.69936336321355
# peak = 50.331581844089357
# running Working_Memory#20160809-101533-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 213.02021205011633
# _max_rate_low = 149.0873378516019
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.050780737155847
# act_510 = 25.314942299011911
# peak = 52.096544776925896
# running Working_Memory#20160809-101537-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 217.443422048731
# _max_rate_low = 115.63293727279182
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 40.753720265628687
# act_510 = 23.558168794575987
# peak = 47.557067936003705
# running Working_Memory#20160809-101540-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 247.06903497223513
# _max_rate_low = 147.97657652422518
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 49.516621795616764
# act_510 = 27.896602372892495
# peak = 57.669626257502081
# running Working_Memory#20160809-101544-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 236.69574740927422
# _max_rate_low = 139.42155771847536
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 46.958616877090286
# act_510 = 26.562644400029235
# peak = 55.134192556833227
# running Working_Memory#20160809-101548-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 211.7459235118525
# _max_rate_low = 149.22477615323768
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.053487911591347
# act_510 = 25.326229722244843
# peak = 51.566871370951752
# running Working_Memory#20160809-101552-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 208.8619189058848
# _max_rate_low = 149.37069926615038
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.809408894869001
# act_510 = 25.124246903445108
# peak = 51.459539271843937
# running Working_Memory#20160809-101556-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 214.35404915643892
# _max_rate_low = 142.66642225969247
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.71138415074892
# act_510 = 25.092087340307501
# peak = 51.509860339036322
# running Working_Memory#20160809-101559-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 195.42901229940958
# _max_rate_low = 116.47200178435946
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 37.90666393994919
# act_510 = 21.903715968561137
# peak = 44.094011591760996
# running Working_Memory#20160809-101603-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 235.4483800635695
# _max_rate_low = 142.2515420838045
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 46.784306649378543
# act_510 = 26.789558078194698
# peak = 54.772626485289443
# running Working_Memory#20160809-101607-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 231.15856730440925
# _max_rate_low = 130.49211456778104
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.152788515840925
# act_510 = 25.562758126023461
# peak = 52.277444209173112
# running Working_Memory#20160809-101611-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 232.01879137413113
# _max_rate_low = 112.12807008166291
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.18207084889324
# act_510 = 24.643362136016407
# peak = 50.336535575776423
# running Working_Memory#20160809-101615-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 227.37551106340192
# _max_rate_low = 130.64664453312727
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.937038576831256
# act_510 = 25.377125776008704
# peak = 51.956649278425402
# running Working_Memory#20160809-101619-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 242.224222977192
# _max_rate_low = 129.74107214651644
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 45.89510654506509
# act_510 = 26.246443994468869
# peak = 54.449107676959066
# running Working_Memory#20160809-101622-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 226.75404229399484
# _max_rate_low = 121.58355415244164
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.892580333566549
# act_510 = 24.433022900389886
# peak = 49.899182552914588
# running Working_Memory#20160809-101626-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 231.1266812122393
# _max_rate_low = 135.5567632881042
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 45.27393564833897
# act_510 = 25.25796226809074
# peak = 53.386189673600747
# running Working_Memory#20160809-101630-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 240.53431148421836
# _max_rate_low = 129.2101717277988
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 46.187618630836468
# act_510 = 26.102616591819061
# peak = 53.617073780056671
# running Working_Memory#20160809-101634-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 248.49526838521507
# _max_rate_low = 100.41146704167261
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.704157216689261
# act_510 = 24.881608424202994
# peak = 51.105271544774524
# running Working_Memory#20160809-101638-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 223.2956240473988
# _max_rate_low = 121.92175379429392
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 41.864062462628212
# act_510 = 24.38718181528721
# peak = 49.811406526444699
# running Working_Memory#20160809-101642-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 229.44080645140474
# _max_rate_low = 126.78245321461903
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.442719451830371
# act_510 = 24.870476944053451
# peak = 51.480361692816366
# running Working_Memory#20160809-101646-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 238.22914728055443
# _max_rate_low = 132.52578047754383
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 46.211697938292659
# act_510 = 26.283913372577953
# peak = 54.329245833192317
# running Working_Memory#20160809-101649-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 170.52898404037757
# _max_rate_low = 116.26319727423238
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 34.690635308393219
# act_510 = 20.070568887118608
# peak = 40.671426182993159
# running Working_Memory#20160809-101653-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 249.51794019159368
# _max_rate_low = 124.1600008554232
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 46.815680209731177
# act_510 = 26.663643886156787
# peak = 54.500706994750125
# running Working_Memory#20160809-101656-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 218.4778252404117
# _max_rate_low = 119.27690786049342
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 41.27330540321114
# act_510 = 23.449385021289654
# peak = 48.420123745156964
# running Working_Memory#20160809-101700-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 188.12424680333834
# _max_rate_low = 130.29970323488536
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 37.80841409746332
# act_510 = 22.008460431351203
# peak = 45.180758664375212
# running Working_Memory#20160809-101704-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 202.68217565615817
# _max_rate_low = 135.00307396406242
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 40.80462668234938
# act_510 = 23.993261479910554
# peak = 48.844283204271782
# running Working_Memory#20160809-101708-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 222.20790631528908
# _max_rate_low = 112.32710608696851
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 40.986549327068509
# act_510 = 23.474486863816342
# peak = 48.297252377422033
# running Working_Memory#20160809-101712-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 150.1132770463531
# _max_rate_low = 126.80159982905626
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 33.236786315425626
# act_510 = 19.51187724046526
# peak = 39.685106408802824
# running Working_Memory#20160809-101715-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 196.19455933592783
# _max_rate_low = 131.56639136403996
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 39.654263935714212
# act_510 = 22.564017157471898
# peak = 47.638654037869742
# running Working_Memory#20160809-101719-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 243.56753439347736
# _max_rate_low = 137.11727229298052
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 47.520540990853974
# act_510 = 27.315785016325183
# peak = 55.640522949861058
# running Working_Memory#20160809-101723-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 187.52974295007718
# _max_rate_low = 119.50172479062735
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 37.207215402101376
# act_510 = 21.344401478597934
# peak = 44.342903031513266
# running Working_Memory#20160809-101727-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 234.06669242840616
# _max_rate_low = 140.36462374880878
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 46.481043888955725
# act_510 = 26.363494696010704
# peak = 54.652622687152075
# running Working_Memory#20160809-101730-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 226.87925360502976
# _max_rate_low = 133.69959971860013
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.251495502655317
# act_510 = 25.350935427215983
# peak = 51.879664287906316
# running Working_Memory#20160809-101734-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 207.29570990608528
# _max_rate_low = 124.34294508470113
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 39.941362103625153
# act_510 = 23.366919162234421
# peak = 48.411455364578465
# running Working_Memory#20160809-101738-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 198.75381537559377
# _max_rate_low = 113.41950048796227
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 38.071519574154408
# act_510 = 21.977358962341803
# peak = 44.686570375097055
# running Working_Memory#20160809-101742-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 216.16812837778016
# _max_rate_low = 104.18890756924384
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 39.226571386613941
# act_510 = 22.342737428982655
# peak = 46.363617895740497
# running Working_Memory#20160809-101746-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 191.5322623636742
# _max_rate_low = 127.39677083985937
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 38.202625206807348
# act_510 = 22.424890636253107
# peak = 45.100288188656911
# running Working_Memory#20160809-101749-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 210.82712449469105
# _max_rate_low = 110.06009891018954
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 39.45851950329093
# act_510 = 22.404477792349827
# peak = 46.070900638260696
# running Working_Memory#20160809-101753-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 239.84385012093054
# _max_rate_low = 122.79637437908838
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.864599735632289
# act_510 = 25.753856457068558
# peak = 52.969142867159476
# running Working_Memory#20160809-101757-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 239.37442123925018
# _max_rate_low = 102.519196226049
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.891482353100074
# act_510 = 24.370755974949699
# peak = 49.881750113571883
# running Working_Memory#20160809-101801-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 246.5594841299105
# _max_rate_low = 118.66530209807897
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 45.560507054577911
# act_510 = 26.076960344842441
# peak = 53.302869956838023
# running Working_Memory#20160809-101804-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 220.43259423840624
# _max_rate_low = 122.65840171930806
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.005946055805147
# act_510 = 24.158424910811853
# peak = 49.511323310941613
# running Working_Memory#20160809-101808-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 177.2651671851742
# _max_rate_low = 107.20524245275371
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 33.9576870595969
# act_510 = 19.830132911587629
# peak = 41.093092406230973
# running Working_Memory#20160809-101812-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 234.57675756017616
# _max_rate_low = 109.3797966538991
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.654227526425935
# act_510 = 24.105228298631172
# peak = 50.077207112057948
# running Working_Memory#20160809-101816-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 243.52655942456698
# _max_rate_low = 144.38479769465008
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 48.670863135196555
# act_510 = 27.71066281393356
# peak = 56.850158040524391
# running Working_Memory#20160809-101819-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 203.21891198389093
# _max_rate_low = 117.74501313026474
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 39.027132611141546
# act_510 = 22.849353398385734
# peak = 46.36509487129122
# running Working_Memory#20160809-101823-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 228.8135429638578
# _max_rate_low = 131.17434629011706
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.277878793619443
# act_510 = 25.561585693426107
# peak = 52.041681754268801
# running Working_Memory#20160809-101826-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 224.52858879835475
# _max_rate_low = 127.7511286662128
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.297643504039527
# act_510 = 24.869893098579375
# peak = 51.348857177353537
# running Working_Memory#20160809-101830-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 232.20544025728825
# _max_rate_low = 138.6488602981635
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 46.11540205789025
# act_510 = 26.528822106650122
# peak = 53.762419574407872
# running Working_Memory#20160809-101833-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 236.9435010086804
# _max_rate_low = 125.66744805666596
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.998929562538699
# act_510 = 25.525982064585854
# peak = 53.021979946506981
# running Working_Memory#20160809-101837-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 246.17405168837473
# _max_rate_low = 114.70228741744282
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 45.072825653635959
# act_510 = 25.712230162342941
# peak = 52.804791056937212
# running Working_Memory#20160809-101841-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 249.57540082089608
# _max_rate_low = 125.88840893289743
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 47.003183474100176
# act_510 = 26.756170820483629
# peak = 54.729801612966163
# running Working_Memory#20160809-101844-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 237.62957858893884
# _max_rate_low = 123.28164295661828
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.741784538861445
# act_510 = 25.885307217518715
# peak = 52.35227813880168
# running Working_Memory#20160809-101848-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 241.32889264786047
# _max_rate_low = 128.49890613836538
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 46.480739691100233
# act_510 = 26.173848882677515
# peak = 53.81424246502749
# running Working_Memory#20160809-101852-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 230.74716186231507
# _max_rate_low = 133.7941187061791
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.862132030246393
# act_510 = 25.381762244289686
# peak = 53.278530535680986
# running Working_Memory#20160809-101856-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 215.0332392354972
# _max_rate_low = 136.18039484483214
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.982601195874253
# act_510 = 24.738522956971941
# peak = 50.521195740382836
# running Working_Memory#20160809-101859-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# ...
# N = 265
# act_1750 = 39.647808675683955
# act_510 = 22.988994754446534
# peak = 47.198683798533111
# running Working_Memory#20160809-102425-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 232.8767365118118
# _max_rate_low = 117.66826854545943
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.17652322757683
# act_510 = 24.731761186173195
# peak = 50.753252657888979
# running Working_Memory#20160809-102428-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 219.14898524227718
# _max_rate_low = 123.1829484817555
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.131236565208368
# act_510 = 23.944879044669936
# peak = 48.781744907662798
# running Working_Memory#20160809-102431-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 246.65790587113835
# _max_rate_low = 111.6188300772035
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.419478344594452
# act_510 = 25.43410278598202
# peak = 52.607557851563108
# running Working_Memory#20160809-102435-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 222.715450024447
# _max_rate_low = 131.96747785473062
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.352064468364091
# act_510 = 24.983041951016251
# peak = 51.154279977242396
# running Working_Memory#20160809-102439-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 236.00159929305536
# _max_rate_low = 109.23170243600839
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.086670895071578
# act_510 = 24.320276785457619
# peak = 50.383373617350713
# running Working_Memory#20160809-102442-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 216.01896030897942
# _max_rate_low = 124.49807591064635
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 41.635951460582227
# act_510 = 23.810472323757164
# peak = 49.026062754482354
# running Working_Memory#20160809-102445-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 238.03227653619132
# _max_rate_low = 134.22142832866254
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 46.35638464590324
# act_510 = 26.095743698065995
# peak = 54.238696093706345
# running Working_Memory#20160809-102448-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 227.1440369562024
# _max_rate_low = 110.5353529569795
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 41.100634263978961
# act_510 = 23.703362712190678
# peak = 49.16586270641767
# running Working_Memory#20160809-102451-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 213.29576435294715
# _max_rate_low = 112.59031386520671
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 39.618794951080666
# act_510 = 22.639006721192107
# peak = 46.977393469913984
# running Working_Memory#20160809-102454-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 229.991698063546
# _max_rate_low = 121.97478704210948
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.109636493300719
# act_510 = 24.735049213480782
# peak = 51.031214166991028
# running Working_Memory#20160809-102457-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 243.81803465010597
# _max_rate_low = 115.23307983226039
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.033917837795343
# act_510 = 25.33163191598296
# peak = 52.315404138275966
# running Working_Memory#20160809-102459-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 249.66034791167536
# _max_rate_low = 119.69731127580692
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 45.774995766299064
# act_510 = 26.244803732014457
# peak = 54.144355614449708
# running Working_Memory#20160809-102502-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 241.26079966316803
# _max_rate_low = 123.62741145353864
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 45.170829254271062
# act_510 = 25.481599945738591
# peak = 53.135672157023699
# running Working_Memory#20160809-102505-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 217.57780804927788
# _max_rate_low = 118.43348688730981
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 40.940138708993153
# act_510 = 23.604566994306612
# peak = 48.323720829801509
# running Working_Memory#20160809-102508-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 174.5106545106286
# _max_rate_low = 115.96435437102278
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 34.963070692970291
# act_510 = 20.409547628605729
# peak = 41.612791665519829
# running Working_Memory#20160809-102511-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 233.39125736946386
# _max_rate_low = 108.32875871154029
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.30971535637147
# act_510 = 24.27513972125303
# peak = 49.436628799364719
# running Working_Memory#20160809-102514-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 224.67193367188523
# _max_rate_low = 125.2883782996564
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 42.987931866714241
# act_510 = 24.504584504637211
# peak = 50.329726419695504
# running Working_Memory#20160809-102517-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 209.49792507124644
# _max_rate_low = 130.041168339318
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 41.19122902420861
# act_510 = 23.431863319063218
# peak = 48.835400756861496
# running Working_Memory#20160809-102520-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 245.05215081414872
# _max_rate_low = 114.11200043554992
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.547804015934872
# act_510 = 25.672733750581308
# peak = 52.70779592195796
# running Working_Memory#20160809-102523-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 240.02635625625203
# _max_rate_low = 127.19764664649553
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 45.069366562473675
# act_510 = 26.008956515478967
# peak = 53.442385877750304
# running Working_Memory#20160809-102526-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 167.15349621006965
# _max_rate_low = 121.6298154669742
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 34.539209947059582
# act_510 = 20.200873230604309
# peak = 41.179769650471286
# running Working_Memory#20160809-102529-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 231.22850127203674
# _max_rate_low = 133.0160502210975
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.293496097146786
# act_510 = 25.40810540639103
# peak = 52.757304240833776
# running Working_Memory#20160809-102532-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 230.92246164638843
# _max_rate_low = 135.61921477922613
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 45.510905804190465
# act_510 = 25.216719666428631
# peak = 53.075549550770056
# running Working_Memory#20160809-102535-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 228.44250305996502
# _max_rate_low = 133.42448996998894
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 44.886551499578111
# act_510 = 25.494758760949047
# peak = 52.266862080308719
# running Working_Memory#20160809-102538-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1376503648029975
# _max_rate_high = 221.12228519074665
# _max_rate_low = 132.60321020466085
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.566233343359727
# act_510 = 25.123016790160111
# peak = 50.843860141714607

# %%
print(best)
# Out:
# {'max_rate_high': 243.49876526852984, 'max_rate_low': 119.37357766469393}

# %%
import pandas
import seaborn as sns
data = ctn_benchmark.Data('data')
df = pandas.DataFrame(data.data)
df = df[df._input_scale == 0.38314316705290097]
df = df[df._intercept_low == -0.4989080091138938]
df = df[df._tau_reset == 0.1376503648029975]
df = df[df._tau_input == 0.009683186948674292]
df = df[df._tau_recurrent == 0.1959772077772586]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = '_max_rate_low'
sns.regplot(x, y = 'act_510', ax = ax1, data = df)
sns.regplot(x, y = 'act_1750', ax = ax2, data = df)
sns.regplot(x, y = 'peak', ax = ax3, data = df)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = '_max_rate_high'
sns.regplot(x, y = 'act_510', ax = ax1, data = df)
sns.regplot(x, y = 'act_1750', ax = ax2, data = df)
sns.regplot(x, y = 'peak', ax = ax3, data = df)

# %%
df['max_rate_range'] = df['_max_rate_high']-df['_max_rate_low']
fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = 'max_rate_range'
sns.regplot(x, y = 'act_510', ax = ax1, data = df)
sns.regplot(x, y = 'act_1750', ax = ax2, data = df)
sns.regplot(x, y = 'peak', ax = ax3, data = df)

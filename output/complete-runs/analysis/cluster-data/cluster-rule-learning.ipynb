# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# # Loading and Combining the Clustered and Binned Data

# %% [markdown]
# ## Markdown Cells

# %%
# load in cluster data 
md_cluster_original = pd.read_csv('markdown_group_clusters.csv')

# %%
# initial look at the data
md_cluster_original.head()
# Out:
#    Unnamed: 0  nb_id  longer_beginning  longer_ending  has_author  \
# 0           0    594              True          False       False
# 1           1   1222              True          False       False
# 2           2   1447              True          False       False
# 3           3   2705              True          False       False
# 4           4   2861              True          False       False
#
#    has_equation  jupyter_prop  output_cell_prop  markdown_prop  num_contrib  \
# 0         False      0.507588          1.000000       0.044444          3.0
# 1         False      1.000000          0.000000       0.161290          1.0
# 2         False      0.970851          0.011364       0.375887          1.0
# 3         False      1.000000          0.500000       0.461538          1.0
# 4          True      1.000000          0.214286       0.461538          1.0
#
#    ...  md_format  non_exec_prop  exec_inorder  exec_skips  has_error  \
# 0  ...       True       0.000000      1.000000    1.809524      False
# 1  ...       True       0.961538      1.000000    0.000000      False
# 2  ...       True       0.988636      1.000000    0.000000      False
# 3  ...      False       0.000000      0.923077    1.615385      False
# 4  ...      False       0.000000      1.000000    6.333333      False
#
#    has_export  num_functions  has_test  num_headers  cluster
# 0       False            0.0     False          7.0        1
# 1       False            0.0     False          5.0        1
# 2        True           15.0     False         30.0        3
# 3       False            6.0     False          7.0        1
# 4       False            0.0     False          1.0        1
#
# [5 rows x 27 columns]

# %%
# copy the cluster column
md_cluster_col = md_cluster_original['cluster'].copy()

# %%
# load in binned data 
md_binned_original = pd.read_csv('../binning-data/markdown_group_binned.csv')

# %%
# initial look at the data
md_binned_original.head()
# Out:
#    Unnamed: 0  nb_id  longer_beginning  longer_ending  has_author  \
# 0           0    594              True          False       False
# 1           1   1222              True          False       False
# 2           2   1447              True          False       False
# 3           3   2705              True          False       False
# 4           4   2861              True          False       False
#
#    has_equation jupyter_prop output_cell_prop markdown_prop num_contrib  ...  \
# 0         False       medium             high           low       lower  ...
# 1         False         high              low        medium       lower  ...
# 2         False         high              low        medium       lower  ...
# 3         False         high           medium        medium       lower  ...
# 4          True         high              low        medium       lower  ...
#
#   num_commits  md_format  non_exec_prop  exec_inorder exec_skips  has_error  \
# 0       lower       True            low        higher      lower      False
# 1       lower       True           high        higher      lower      False
# 2       lower       True           high        higher      lower      False
# 3       lower      False            low        higher      lower      False
# 4       lower      False            low        higher      lower      False
#
#   has_export  num_functions has_test num_headers
# 0      False          lower    False      medium
# 1      False          lower    False      medium
# 2       True         higher    False        high
# 3      False          lower    False      medium
# 4      False          lower    False         low
#
# [5 rows x 26 columns]

# %%
# create a copy of the binned dataframe we will modify
md_df = md_binned_original.copy()

# drop the first column
md_df = md_df.drop(['Unnamed: 0'], axis = 1)

# %%
# check that the nb_id columns match up
print((md_df['nb_id'] == md_cluster_original['nb_id']).value_counts())
# Out:
# True    2291
# Name: nb_id, dtype: int64

# %%
# add the cluster column to the dataframe
md_df['cluster'] = md_cluster_col

# drop the first column
md_df = md_df.drop(['nb_id'], axis = 1)

# check the data
md_df.head()
# Out:
#    longer_beginning  longer_ending  has_author  has_equation jupyter_prop  \
# 0              True          False       False         False       medium
# 1              True          False       False         False         high
# 2              True          False       False         False         high
# 3              True          False       False         False         high
# 4              True          False       False          True         high
#
#   output_cell_prop markdown_prop num_contrib image_prop  is_education  ...  \
# 0             high           low       lower        low          True  ...
# 1              low        medium       lower        low          True  ...
# 2              low        medium       lower        low          True  ...
# 3           medium        medium       lower        low          True  ...
# 4              low        medium       lower        low         False  ...
#
#    md_format  non_exec_prop exec_inorder  exec_skips has_error  has_export  \
# 0       True            low       higher       lower     False       False
# 1       True           high       higher       lower     False       False
# 2       True           high       higher       lower     False        True
# 3      False            low       higher       lower     False       False
# 4      False            low       higher       lower     False       False
#
#   num_functions has_test num_headers  cluster
# 0         lower    False      medium        1
# 1         lower    False      medium        1
# 2        higher    False        high        3
# 3         lower    False      medium        1
# 4         lower    False         low        1
#
# [5 rows x 25 columns]

# %%
# check the number of notebooks per cluster
md_df['cluster'].value_counts()
# Out:
# 1    1713
# 3     411
# 2     152
# 0      15
# Name: cluster, dtype: int64

# %%
# separate the clusters
md_clusters = []
for i in range(4):
    cluster = md_df[md_df['cluster'] == i].copy()
    md_clusters.append(cluster)

# %%
# check that the clusters were separated correctly
for cluster in md_clusters:
    print(cluster['cluster'].value_counts())
# Out:
# 0    15
# Name: cluster, dtype: int64
# 1    1713
# Name: cluster, dtype: int64
# 2    152
# Name: cluster, dtype: int64
# 3    411
# Name: cluster, dtype: int64

# %%
# drop the cluster column from each cluster dataframe
for (i, cluster) in enumerate(md_clusters):
    md_clusters[i] = cluster.drop(['cluster'], axis = 1)

# %% [markdown]
# ## No Markdown Cells

# %%
# load in cluster data
no_md_cluster_original = pd.read_csv('no_markdown_group_clusters.csv')

# %%
# initial look at the data
no_md_cluster_original.head()
# Out:
#    Unnamed: 0  nb_id  has_author  jupyter_prop  output_cell_prop  num_contrib  \
# 0           0   1589       False      0.714130          0.538462          1.0
# 1           1   1919       False      0.997840          0.780488          1.0
# 2           2   2857       False      0.121957          0.461538          5.0
# 3           3   4339       False      1.000000          0.190476          1.0
# 4           4   4659       False      0.940063          0.125000          3.0
#
#    image_prop  is_education  has_comments  num_commits  non_exec_prop  \
# 0    0.142857         False         False          1.0        0.00000
# 1    0.187500         False          True          1.0        0.04878
# 2    0.000000         False          True         11.0        0.00000
# 3    0.000000         False          True          1.0        0.00000
# 4    0.000000         False          True          3.0        0.12500
#
#    exec_inorder  exec_skips  has_error  has_export  num_functions  has_test  \
# 0      1.000000    1.000000      False        True            2.0     False
# 1      0.789474   10.631579       True        True            5.0     False
# 2      0.909091    6.181818      False        True            0.0     False
# 3      1.000000    1.631579      False       False            1.0     False
# 4      1.000000    1.000000       True       False            3.0     False
#
#    cluster
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
# copy the cluster column
no_md_cluster_col = no_md_cluster_original['cluster'].copy()

# %%
# load in binned data
no_md_binned_original = pd.read_csv('../binning-data/no_markdown_group_binned.csv')

# %%
# initial look at the data
no_md_binned_original.head()
# Out:
#    Unnamed: 0  nb_id  has_author jupyter_prop output_cell_prop num_contrib  \
# 0           0   1589       False       medium           medium       lower
# 1           1   1919       False         high             high       lower
# 2           2   2857       False          low           medium      higher
# 3           3   4339       False         high              low       lower
# 4           4   4659       False         high              low       lower
#
#   image_prop  is_education  has_comments num_commits non_exec_prop  \
# 0        low         False         False       lower         lower
# 1        low         False          True       lower         lower
# 2        low         False          True      higher         lower
# 3        low         False          True       lower         lower
# 4        low         False          True      higher         lower
#
#   exec_inorder exec_skips  has_error  has_export num_functions  has_test
# 0       higher      lower      False        True         lower     False
# 1       higher      lower       True        True         lower     False
# 2       higher      lower      False        True         lower     False
# 3       higher      lower      False       False         lower     False
# 4       higher      lower       True       False         lower     False

# %%
# create a copy
no_md_df = no_md_binned_original.copy()

# drop the first column
no_md_df = no_md_df.drop(['Unnamed: 0'], axis = 1)

# %% [markdown]
# When doing clustering for the no markdown cell group, we filtered out a notebook that was in a cluster by itself. We do the same for the binned data

# %%
# drop notebook
no_md_df = no_md_df[no_md_df['nb_id'] != 588262].reset_index()

# %%
# check that the nb_id columns match up
print((no_md_df['nb_id'] == no_md_cluster_original['nb_id']).value_counts())
# Out:
# True    1353
# Name: nb_id, dtype: int64

# %%
# add the cluster column to the dataframe
no_md_df['cluster'] = no_md_cluster_col

# drop the first two columns
no_md_df = no_md_df.drop(['nb_id', 'index'], axis = 1)

no_md_df.head()
# Out:
#    has_author jupyter_prop output_cell_prop num_contrib image_prop  \
# 0       False       medium           medium       lower        low
# 1       False         high             high       lower        low
# 2       False          low           medium      higher        low
# 3       False         high              low       lower        low
# 4       False         high              low       lower        low
#
#    is_education  has_comments num_commits non_exec_prop exec_inorder  \
# 0         False         False       lower         lower       higher
# 1         False          True       lower         lower       higher
# 2         False          True      higher         lower       higher
# 3         False          True       lower         lower       higher
# 4         False          True      higher         lower       higher
#
#   exec_skips  has_error  has_export num_functions  has_test  cluster
# 0      lower      False        True         lower     False        1
# 1      lower       True        True         lower     False        1
# 2      lower      False        True         lower     False        1
# 3      lower      False       False         lower     False        1
# 4      lower       True       False         lower     False        1

# %%
# check the number of notebooks per cluster
no_md_df['cluster'].value_counts()
# Out:
# 1    1116
# 2     145
# 0      73
# 3      19
# Name: cluster, dtype: int64

# %%
# separate the clusters
no_md_clusters = []
for i in range(4):
    cluster = no_md_df[no_md_df['cluster'] == i].copy()
    no_md_clusters.append(cluster)

# %%
# check that the clusters were separated correctly
for cluster in no_md_clusters:
    print(cluster['cluster'].value_counts())
# Out:
# 0    73
# Name: cluster, dtype: int64
# 1    1116
# Name: cluster, dtype: int64
# 2    145
# Name: cluster, dtype: int64
# 3    19
# Name: cluster, dtype: int64

# %%
# drop the cluster column
for (i, cluster) in enumerate(no_md_clusters):
    no_md_clusters[i] = cluster.drop(['cluster'], axis = 1)

# %% [markdown]
# # One-Hot Encoding

# %% [markdown]
# ## Markdown Cells

# %%
# create copies of the clusters that we will one-hot encode
md_clusters_onehot = []
for i in range(4):
    md_clusters_onehot.append(md_clusters[i].copy())

# %%
# change True/False to T/F and medium to med
for (i, cluster) in enumerate(md_clusters_onehot):
    cluster = cluster.replace(True, 'T')
    cluster = cluster.replace(False, 'F')
    cluster = cluster.replace('medium', 'med')
    md_clusters_onehot[i] = cluster

# %%
# check the data
md_clusters_onehot[0].head()
# Out:
#     longer_beginning longer_ending has_author has_equation jupyter_prop  \
# 38                 F             T          F            F         high
# 174                F             F          F            F         high
# 261                T             F          F            F         high
# 262                T             F          F            F         high
# 263                T             F          F            F         high
#
#     output_cell_prop markdown_prop num_contrib image_prop is_education  ...  \
# 38               med           med       lower        med            F  ...
# 174              med           med       lower        med            T  ...
# 261             high           med       lower        med            F  ...
# 262             high           med       lower        med            F  ...
# 263             high           med       lower        med            F  ...
#
#     num_commits md_format non_exec_prop exec_inorder exec_skips has_error  \
# 38        lower         T           low       higher     higher         F
# 174       lower         F           low       higher     higher         F
# 261       lower         F           low       higher     higher         T
# 262       lower         F           low       higher     higher         T
# 263       lower         F           low       higher     higher         T
#
#     has_export num_functions has_test num_headers
# 38           F         lower        F        high
# 174          F         lower        F         med
# 261          F        higher        F         low
# 262          F        higher        F         low
# 263          F        higher        F         low
#
# [5 rows x 24 columns]

# %%
# one-hot encode the clusters
for (i, cluster) in enumerate(md_clusters_onehot):
    cluster = pd.get_dummies(cluster)
    md_clusters_onehot[i] = cluster

# %%
# check the data
md_clusters_onehot[0].head()
# Out:
#      longer_beginning_F  longer_beginning_T  longer_ending_F  longer_ending_T  \
# 38                    1                   0                0                1
# 174                   1                   0                1                0
# 261                   0                   1                1                0
# 262                   0                   1                1                0
# 263                   0                   1                1                0
#
#      has_author_F  has_author_T  has_equation_F  has_equation_T  \
# 38              1             0               1               0
# 174             1             0               1               0
# 261             1             0               1               0
# 262             1             0               1               0
# 263             1             0               1               0
#
#      jupyter_prop_high  jupyter_prop_low  ...  has_error_F  has_error_T  \
# 38                   1                 0  ...            1            0
# 174                  1                 0  ...            1            0
# 261                  1                 0  ...            0            1
# 262                  1                 0  ...            0            1
# 263                  1                 0  ...            0            1
#
#      has_export_F  has_export_T  num_functions_higher  num_functions_lower  \
# 38              1             0                     0                    1
# 174             1             0                     0                    1
# 261             1             0                     1                    0
# 262             1             0                     1                    0
# 263             1             0                     1                    0
#
#      has_test_F  num_headers_high  num_headers_low  num_headers_med
# 38            1                 1                0                0
# 174           1                 0                0                1
# 261           1                 0                1                0
# 262           1                 0                1                0
# 263           1                 0                1                0
#
# [5 rows x 48 columns]

# %% [markdown]
# ## No Markdown Cells

# %%
# create copies that we will one-hot encode
no_md_clusters_onehot = []
for i in range(4):
    no_md_clusters_onehot.append(no_md_clusters[i].copy())

# %%
# change True/False to T/F and medium to med
for (i, cluster) in enumerate(no_md_clusters_onehot):
    cluster = cluster.replace(True, 'T')
    cluster = cluster.replace(False, 'F')
    cluster = cluster.replace('medium', 'med')
    no_md_clusters_onehot[i] = cluster

# %%
# check the data
no_md_clusters_onehot[0].head()
# Out:
#     has_author jupyter_prop output_cell_prop num_contrib image_prop  \
# 6            F          low              med       lower        low
# 73           F         high             high       lower        low
# 101          F         high              med       lower        low
# 133          F         high              med       lower        med
# 134          F         high              med       lower        med
#
#     is_education has_comments num_commits non_exec_prop exec_inorder  \
# 6              F            T       lower         lower       higher
# 73             F            T       lower         lower       higher
# 101            F            T      higher         lower       higher
# 133            F            T       lower         lower       higher
# 134            F            T       lower         lower       higher
#
#     exec_skips has_error has_export num_functions has_test
# 6        lower         T          T        higher        F
# 73       lower         F          F        higher        F
# 101      lower         F          F        higher        F
# 133      lower         T          T        higher        F
# 134      lower         T          T        higher        F

# %%
# one-hot encode the clusters
for (i, cluster) in enumerate(no_md_clusters_onehot):
    cluster = pd.get_dummies(cluster)
    no_md_clusters_onehot[i] = cluster

# %%
# check the data
no_md_clusters_onehot[0].head()
# Out:
#      has_author_F  has_author_T  jupyter_prop_high  jupyter_prop_low  \
# 6               1             0                  0                 1
# 73              1             0                  1                 0
# 101             1             0                  1                 0
# 133             1             0                  1                 0
# 134             1             0                  1                 0
#
#      jupyter_prop_med  output_cell_prop_high  output_cell_prop_low  \
# 6                   0                      0                     0
# 73                  0                      1                     0
# 101                 0                      0                     0
# 133                 0                      0                     0
# 134                 0                      0                     0
#
#      output_cell_prop_med  num_contrib_higher  num_contrib_lower  ...  \
# 6                       1                   0                  1  ...
# 73                      0                   0                  1  ...
# 101                     1                   0                  1  ...
# 133                     1                   0                  1  ...
# 134                     1                   0                  1  ...
#
#      exec_inorder_higher  exec_inorder_lower  exec_skips_higher  \
# 6                      1                   0                  0
# 73                     1                   0                  0
# 101                    1                   0                  0
# 133                    1                   0                  0
# 134                    1                   0                  0
#
#      exec_skips_lower  has_error_F  has_error_T  has_export_F  has_export_T  \
# 6                   1            0            1             0             1
# 73                  1            1            0             1             0
# 101                 1            1            0             1             0
# 133                 1            0            1             0             1
# 134                 1            0            1             0             1
#
#      num_functions_higher  has_test_F
# 6                       1           1
# 73                      1           1
# 101                     1           1
# 133                     1           1
# 134                     1           1
#
# [5 rows x 30 columns]

# %% [markdown]
# # Performing the Apriori Algorithm

# %% [markdown]
# ## Markdown Cells

# %%
# change to True/False instead of 1/0
for (i, cluster) in enumerate(md_clusters_onehot):
    cluster = cluster.replace(1, True)
    cluster = cluster.replace(0, False)
    md_clusters_onehot[i] = cluster

# %%
# perform the apriori algorithm on the dataframe 
md_cluster_itemsets = []
for cluster in md_clusters_onehot:
    itemset = apriori(cluster, min_support = 0.5, use_colnames = True)
    md_cluster_itemsets.append(itemset)

# %%
# look at an itemset
md_cluster_itemsets[0]
# Out:
#         support                                           itemsets
# 0      0.600000                               (longer_beginning_F)
# 1      0.933333                                  (longer_ending_F)
# 2      0.933333                                     (has_author_F)
# 3      0.933333                                   (has_equation_F)
# 4      0.733333                                (jupyter_prop_high)
# ...         ...                                                ...
# 37370  0.533333  (longer_ending_F, non_exec_prop_low, has_test_...
# 37371  0.533333  (longer_ending_F, non_exec_prop_low, has_test_...
# 37372  0.533333  (longer_ending_F, non_exec_prop_low, has_test_...
# 37373  0.533333  (non_exec_prop_low, has_test_F, num_contrib_lo...
# 37374  0.533333  (longer_ending_F, non_exec_prop_low, has_test_...
#
# [37375 rows x 2 columns]

# %%
# add a column that counts the number of elements in the itemset
for (i, itemset) in enumerate(md_cluster_itemsets):
    itemset['length'] = itemset['itemsets'].apply(len)
    md_cluster_itemsets[i] = itemset

# %%
# check the itemset again
md_cluster_itemsets[0]
# Out:
#         support                                           itemsets  length
# 0      0.600000                               (longer_beginning_F)       1
# 1      0.933333                                  (longer_ending_F)       1
# 2      0.933333                                     (has_author_F)       1
# 3      0.933333                                   (has_equation_F)       1
# 4      0.733333                                (jupyter_prop_high)       1
# ...         ...                                                ...     ...
# 37370  0.533333  (longer_ending_F, non_exec_prop_low, has_test_...      13
# 37371  0.533333  (longer_ending_F, non_exec_prop_low, has_test_...      13
# 37372  0.533333  (longer_ending_F, non_exec_prop_low, has_test_...      13
# 37373  0.533333  (non_exec_prop_low, has_test_F, num_contrib_lo...      13
# 37374  0.533333  (longer_ending_F, non_exec_prop_low, has_test_...      14
#
# [37375 rows x 3 columns]

# %% [markdown]
# ## No Markdown Cells

# %%
# change to True/False instead of 1/0
for (i, cluster) in enumerate(no_md_clusters_onehot):
    cluster = cluster.replace(1, True)
    cluster = cluster.replace(0, False)
    no_md_clusters_onehot[i] = cluster

# %%
# perform apriori algorithm
no_md_cluster_itemsets = []
for cluster in no_md_clusters_onehot:
    itemset = apriori(cluster, min_support = 0.5, use_colnames = True)
    no_md_cluster_itemsets.append(itemset)

# %%
# look at an itemset
no_md_cluster_itemsets[0]
# Out:
#        support                                           itemsets
# 0     0.986301                                     (has_author_F)
# 1     0.780822                                (jupyter_prop_high)
# 2     0.520548                             (output_cell_prop_med)
# 3     0.890411                                (num_contrib_lower)
# 4     0.602740                                   (image_prop_low)
# ...        ...                                                ...
# 2074  0.506849  (num_functions_higher, has_test_F, num_contrib...
# 2075  0.547945  (num_functions_higher, has_test_F, num_contrib...
# 2076  0.506849  (num_functions_higher, has_test_F, num_contrib...
# 2077  0.506849  (num_functions_higher, has_test_F, num_contrib...
# 2078  0.534247  (num_functions_higher, has_test_F, num_contrib...
#
# [2079 rows x 2 columns]

# %%
# add a column that records length
for (i, itemset) in enumerate(no_md_cluster_itemsets):
    itemset['length'] = itemset['itemsets'].apply(len)
    no_md_cluster_itemsets[i] = itemset

# %%
# check the itemset again
no_md_cluster_itemsets[0]
# Out:
#        support                                           itemsets  length
# 0     0.986301                                     (has_author_F)       1
# 1     0.780822                                (jupyter_prop_high)       1
# 2     0.520548                             (output_cell_prop_med)       1
# 3     0.890411                                (num_contrib_lower)       1
# 4     0.602740                                   (image_prop_low)       1
# ...        ...                                                ...     ...
# 2074  0.506849  (num_functions_higher, has_test_F, num_contrib...       9
# 2075  0.547945  (num_functions_higher, has_test_F, num_contrib...       9
# 2076  0.506849  (num_functions_higher, has_test_F, num_contrib...       9
# 2077  0.506849  (num_functions_higher, has_test_F, num_contrib...       9
# 2078  0.534247  (num_functions_higher, has_test_F, num_contrib...       9
#
# [2079 rows x 3 columns]

# %% [markdown]
# # Extracting Association Rules

# %% [markdown]
# ## Markdown Cells

# %%
# use itemsets to extract association rules for each cluster
md_cluster_rules = []
for itemset in md_cluster_itemsets:
    rules = association_rules(itemset, metric = 'confidence', min_threshold = 0.95)
    md_cluster_rules.append(rules)

# %%
# look at the sizes of rules
for rule in md_cluster_rules:
    print(len(rule))
# Out:
# 2060266
# 15939
# 6760
# 2055

# %% [markdown]
# I kept upping the threshold to shrink the size of the first rule set, but this is as small as I could get it

# %%
# add columns that hold length
for (i, rule) in enumerate(md_cluster_rules):
    rule['antecedent_len'] = rule['antecedents'].apply(len)
    rule['consequent_len'] = rule['consequents'].apply(len)
    md_cluster_rules[i] = rule

# %% [markdown]
# ## No Markdown Cells

# %%
# use itemsets to extract association rules
no_md_cluster_rules = []
for itemset in no_md_cluster_itemsets:
    rules = association_rules(itemset, metric = 'confidence', min_threshold = 0.95)
    no_md_cluster_rules.append(rules)

# %%
# look at the sizes of rules
for rule in no_md_cluster_rules:
    print(len(rule))
# Out:
# 9515
# 4964
# 5526
# 19670

# %%
# add columns to hold length
for (i, rule) in enumerate(no_md_cluster_rules):
    rule['antecedent_len'] = rule['antecedents'].apply(len)
    rule['consequent_len'] = rule['consequents'].apply(len)
    no_md_cluster_rules[i] = rule

# %% [markdown]
# # Exporting Results

# %%
# export itemsets for markdown cell group
for (i, itemset) in enumerate(md_cluster_itemsets):
    filename = 'md-rule-learning/md_cluster' + str(i) + '_itemsets.pkl'
    itemset.to_pickle(filename)
    filename = 'md-rule-learning/csv-files/md_cluster' + str(i) + '_itemsets.csv'
    itemset.to_csv(filename)

# %%
# export association rules for markdown cell group
for (i, rule) in enumerate(md_cluster_rules):
    filename = 'md-rule-learning/md_cluster' + str(i) + '_association_rules.pkl'
    rule.to_pickle(filename)
    filename = 'md-rule-learning/csv-files/md_cluster' + str(i) + '_association_rules.csv'
    rule.to_csv(filename)

# %%
# export itemsets for no markdown cell group
for (i, itemset) in enumerate(no_md_cluster_itemsets):
    filename = 'no-md-rule-learning/no_md_cluster' + str(i) + '_itemsets.pkl'
    itemset.to_pickle(filename)
    filename = 'no-md-rule-learning/csv-files/no_md_cluster' + str(i) + '_itemsets.csv'
    itemset.to_csv(filename)

# %%
# export association rules for no markdown cell group
for (i, rule) in enumerate(no_md_cluster_rules):
    filename = 'no-md-rule-learning/no_md_cluster' + str(i) + '_association_rules.pkl'
    rule.to_pickle(filename)
    filename = 'no-md-rule-learning/csv-files/no_md_cluster' + str(i) + '_association_rules.csv'
    rule.to_csv(filename)

# %% [markdown]
# # Imports

# %%
import pandas as pd
import prince

# %% [markdown]
# # Loading the Data

# %% [markdown]
# ## Markdown Cells

# %%
md_filepath = 'markdown_group.csv'
md_df = pd.read_csv(md_filepath)

# %%
# save the original dataframe
md_original = md_df

# %%
# clear the first two columns
md_df = md_df.drop(['Unnamed: 0', 'nb_id'], axis = 1)

# %%
# initial look at the data
md_df.head()
# Out:
#    longer_beginning  longer_ending  has_author  has_equation  jupyter_prop  \
# 0              True          False       False         False      0.507588
# 1              True          False       False         False      1.000000
# 2              True          False       False         False      0.970851
# 3              True          False       False         False      1.000000
# 4              True          False       False          True      1.000000
#
#    markdown_prop  num_contrib  image_prop  is_education  has_links  \
# 0       0.044444          3.0         0.0          True       True
# 1       0.161290          1.0         0.0          True       True
# 2       0.375887          1.0         0.0          True       True
# 3       0.461538          1.0         0.0          True       True
# 4       0.461538          1.0         0.0         False      False
#
#    has_comments  md_frequency  has_title  num_commits  md_format  \
# 0         False      0.068182       True          1.0       True
# 1          True      0.333333      False          2.0       True
# 2          True      0.621429       True          1.0       True
# 3          True      0.640000       True          1.0      False
# 4          True      0.520000      False          1.0      False
#
#    non_exec_prop  exec_inorder  exec_skips  has_error
# 0       0.000000      1.000000    1.809524      False
# 1       0.961538      1.000000    0.000000      False
# 2       0.988636      1.000000    0.000000      False
# 3       0.000000      0.923077    1.615385      False
# 4       0.000000      1.000000    6.333333      False

# %%
# extract the column titles
md_vars = list(md_df)
md_vars
# Out:
# ['longer_beginning',
#  'longer_ending',
#  'has_author',
#  'has_equation',
#  'jupyter_prop',
#  'markdown_prop',
#  'num_contrib',
#  'image_prop',
#  'is_education',
#  'has_links',
#  'has_comments',
#  'md_frequency',
#  'has_title',
#  'num_commits',
#  'md_format',
#  'non_exec_prop',
#  'exec_inorder',
#  'exec_skips',
#  'has_error']

# %% [markdown]
# ## No Markdown Cells

# %%
no_md_filepath = 'no_markdown_group.csv'
no_md_df = pd.read_csv(no_md_filepath)

# %%
# save the original dataframe
no_md_original = no_md_df

# %%
# clear the fisrt two columns
no_md_df = no_md_df.drop(['Unnamed: 0', 'nb_id'], axis = 1)

# %%
# initial look at the data
no_md_df.head()
# Out:
#    has_author  jupyter_prop  num_contrib  image_prop  is_education  \
# 0       False      0.714130          1.0    0.142857         False
# 1       False      0.997840          1.0    0.187500         False
# 2       False      0.121957          5.0    0.000000         False
# 3       False      1.000000          1.0    0.000000         False
# 4       False      0.940063          3.0    0.000000         False
#
#    has_comments  num_commits  non_exec_prop  exec_inorder  exec_skips  \
# 0         False          1.0        0.00000      1.000000    1.000000
# 1          True          1.0        0.04878      0.789474   10.631579
# 2          True         11.0        0.00000      0.909091    6.181818
# 3          True          1.0        0.00000      1.000000    1.631579
# 4          True          3.0        0.12500      1.000000    1.000000
#
#    has_error
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True

# %%
# extract the column titles
no_md_vars = list(no_md_df)
no_md_vars
# Out:
# ['has_author',
#  'jupyter_prop',
#  'num_contrib',
#  'image_prop',
#  'is_education',
#  'has_comments',
#  'num_commits',
#  'non_exec_prop',
#  'exec_inorder',
#  'exec_skips',
#  'has_error']

# %% [markdown]
# # Binning the Data
#
# Since we want to do analysis on categorical variables, we turn our quantitative variables categorical by binning

# %% [markdown]
# ## Markdown Cells

# %%
# print the dtypes so we can extract the quantitative variables
list(enumerate(zip(md_vars, md_df.dtypes)))
# Out:
# [(0, ('longer_beginning', dtype('bool'))),
#  (1, ('longer_ending', dtype('bool'))),
#  (2, ('has_author', dtype('bool'))),
#  (3, ('has_equation', dtype('bool'))),
#  (4, ('jupyter_prop', dtype('float64'))),
#  (5, ('markdown_prop', dtype('float64'))),
#  (6, ('num_contrib', dtype('float64'))),
#  (7, ('image_prop', dtype('float64'))),
#  (8, ('is_education', dtype('bool'))),
#  (9, ('has_links', dtype('bool'))),
#  (10, ('has_comments', dtype('bool'))),
#  (11, ('md_frequency', dtype('float64'))),
#  (12, ('has_title', dtype('bool'))),
#  (13, ('num_commits', dtype('float64'))),
#  (14, ('md_format', dtype('bool'))),
#  (15, ('non_exec_prop', dtype('float64'))),
#  (16, ('exec_inorder', dtype('float64'))),
#  (17, ('exec_skips', dtype('float64'))),
#  (18, ('has_error', dtype('bool')))]

# %%
# extract the quantitative variables
md_quant_vars = [md_vars[i] for i in [4, 5, 6, 7, 11, 13, 15, 16, 17]]
md_quant_vars
# Out:
# ['jupyter_prop',
#  'markdown_prop',
#  'num_contrib',
#  'image_prop',
#  'md_frequency',
#  'num_commits',
#  'non_exec_prop',
#  'exec_inorder',
#  'exec_skips']

# %%
# array of quartiles we want to separate the data into (will later combine medium1 and medium2)
four_labels = ['low', 'medium1', 'medium2', 'high']

# %%
# create a copy of the dataframe that we will turn into categorical data
md_cat_df = md_df.copy()

# %%
# for each quantitative field in the data
for quant_var in md_quant_vars:
    
    # change the column in the dataframe so that it is binned into low, medium, and high
    md_cat_df.loc[:, quant_var] = pd.cut(md_cat_df[quant_var], 4, labels = four_labels)
    
    # combine medium1 and medium2 into medium
    md_cat_df.loc[:, quant_var] = md_cat_df[quant_var].replace(['medium1', 'medium2'], 'medium')

# %%
# initial look at the categorical data
md_cat_df.head()
# Out:
#    longer_beginning  longer_ending  has_author  has_equation jupyter_prop  \
# 0              True          False       False         False       medium
# 1              True          False       False         False         high
# 2              True          False       False         False         high
# 3              True          False       False         False         high
# 4              True          False       False          True         high
#
#   markdown_prop num_contrib image_prop  is_education  has_links  has_comments  \
# 0           low         low        low          True       True         False
# 1           low         low        low          True       True          True
# 2        medium         low        low          True       True          True
# 3        medium         low        low          True       True          True
# 4        medium         low        low         False      False          True
#
#   md_frequency  has_title num_commits  md_format non_exec_prop exec_inorder  \
# 0          low       True         low       True           low         high
# 1       medium      False         low       True          high         high
# 2       medium       True         low       True          high         high
# 3       medium       True         low      False           low         high
# 4       medium      False         low      False           low         high
#
#   exec_skips  has_error
# 0        low      False
# 1        low      False
# 2        low      False
# 3        low      False
# 4        low      False

# %%
# check the bin sizes
for quant_var in md_quant_vars:
    print(md_cat_df[quant_var].value_counts())
# Out:
# high      1804
# medium     346
# low        141
# Name: jupyter_prop, dtype: int64
# medium    1672
# low        544
# high        75
# Name: markdown_prop, dtype: int64
# low       2218
# medium      61
# high        12
# Name: num_contrib, dtype: int64
# low       1241
# medium     873
# high       177
# Name: image_prop, dtype: int64
# medium    1276
# high       660
# low        355
# Name: md_frequency, dtype: int64
# low       2192
# medium      90
# high         9
# Name: num_commits, dtype: int64
# low       2003
# high       173
# medium     115
# Name: non_exec_prop, dtype: int64
# high      2078
# medium     209
# low          4
# Name: exec_inorder, dtype: int64
# low       2255
# medium      34
# high         2
# Name: exec_skips, dtype: int64

# %% [markdown]
# Based on this, I think having **two bins** for each quantitative variable is actually best, since in most cases the low/high group is much smaller than the other bins, and analysis might be skewed if we have bins with a very low number of notebooks

# %%
# new labels for only two bins
two_labels = ['lower', 'higher']

# %%
# reset the categorical dataframe to the original dataframe
md_cat_df = md_df.copy()

# %%
# for each quantitative field in the data
for quant_var in md_quant_vars:
    
    # change the column in the dataframe so that it is binned into low, medium, and high
    md_cat_df.loc[:, quant_var] = pd.cut(md_cat_df[quant_var], 2, labels = two_labels)

# %%
# initial look at the new categorical data
md_cat_df.head()
# Out:
#    longer_beginning  longer_ending  has_author  has_equation jupyter_prop  \
# 0              True          False       False         False       higher
# 1              True          False       False         False       higher
# 2              True          False       False         False       higher
# 3              True          False       False         False       higher
# 4              True          False       False          True       higher
#
#   markdown_prop num_contrib image_prop  is_education  has_links  has_comments  \
# 0         lower       lower      lower          True       True         False
# 1         lower       lower      lower          True       True          True
# 2         lower       lower      lower          True       True          True
# 3         lower       lower      lower          True       True          True
# 4         lower       lower      lower         False      False          True
#
#   md_frequency  has_title num_commits  md_format non_exec_prop exec_inorder  \
# 0        lower       True       lower       True         lower       higher
# 1        lower      False       lower       True        higher       higher
# 2       higher       True       lower       True        higher       higher
# 3       higher       True       lower      False         lower       higher
# 4       higher      False       lower      False         lower       higher
#
#   exec_skips  has_error
# 0      lower      False
# 1      lower      False
# 2      lower      False
# 3      lower      False
# 4      lower      False

# %%
# check the bin sizes again
for quant_var in md_quant_vars:
    print(md_cat_df[quant_var].value_counts())
# Out:
# higher    2003
# lower      288
# Name: jupyter_prop, dtype: int64
# lower     1763
# higher     528
# Name: markdown_prop, dtype: int64
# lower     2255
# higher      36
# Name: num_contrib, dtype: int64
# lower     1721
# higher     570
# Name: image_prop, dtype: int64
# higher    1434
# lower      857
# Name: md_frequency, dtype: int64
# lower     2266
# higher      25
# Name: num_commits, dtype: int64
# lower     2081
# higher     210
# Name: non_exec_prop, dtype: int64
# higher    2268
# lower       23
# Name: exec_inorder, dtype: int64
# lower     2284
# higher       7
# Name: exec_skips, dtype: int64

# %% [markdown]
# ## No Markdown Cells

# %%
# print the dtypes so we can extract the quantitative variables
list(enumerate(zip(no_md_vars, no_md_df.dtypes)))
# Out:
# [(0, ('has_author', dtype('bool'))),
#  (1, ('jupyter_prop', dtype('float64'))),
#  (2, ('num_contrib', dtype('float64'))),
#  (3, ('image_prop', dtype('float64'))),
#  (4, ('is_education', dtype('bool'))),
#  (5, ('has_comments', dtype('bool'))),
#  (6, ('num_commits', dtype('float64'))),
#  (7, ('non_exec_prop', dtype('float64'))),
#  (8, ('exec_inorder', dtype('float64'))),
#  (9, ('exec_skips', dtype('float64'))),
#  (10, ('has_error', dtype('bool')))]

# %%
# extract the quantitative variables
no_md_quant_vars = [no_md_vars[i] for i in [1, 2, 3, 6, 7, 8, 9]]
no_md_quant_vars
# Out:
# ['jupyter_prop',
#  'num_contrib',
#  'image_prop',
#  'num_commits',
#  'non_exec_prop',
#  'exec_inorder',
#  'exec_skips']

# %%
# create a copy of the dataframe that we will turn into categorical data
no_md_cat_df = no_md_df.copy()

# %%
# for each quantitative field in the data
for quant_var in no_md_quant_vars:
    
    # change the column in the dataframe so that it is binned into low, medium, and high
    no_md_cat_df.loc[:, quant_var] = pd.cut(no_md_cat_df[quant_var], 4, labels = four_labels)
    
    # combine medium1 and medium2 into medium
    no_md_cat_df.loc[:, quant_var] = no_md_cat_df[quant_var].replace(['medium1', 'medium2'], 'medium')

# %%
# initial look at the categorical data
no_md_cat_df.head()
# Out:
#    has_author jupyter_prop num_contrib image_prop  is_education  has_comments  \
# 0       False       medium         low        low         False         False
# 1       False         high         low        low         False          True
# 2       False          low         low        low         False          True
# 3       False         high         low        low         False          True
# 4       False         high         low        low         False          True
#
#   num_commits non_exec_prop exec_inorder exec_skips  has_error
# 0         low           low         high        low      False
# 1         low           low         high        low       True
# 2      medium           low         high        low      False
# 3         low           low         high        low      False
# 4         low           low         high        low       True

# %%
# check the bin sizes
for quant_var in no_md_quant_vars:
    print(no_md_cat_df[quant_var].value_counts())
# Out:
# high      1040
# medium     254
# low         61
# Name: jupyter_prop, dtype: int64
# low       1323
# medium      29
# high         3
# Name: num_contrib, dtype: int64
# low       916
# medium    281
# high      158
# Name: image_prop, dtype: int64
# low       1338
# medium      16
# high         1
# Name: num_commits, dtype: int64
# low       1178
# medium      93
# high        84
# Name: non_exec_prop, dtype: int64
# high      1165
# medium     169
# low         21
# Name: exec_inorder, dtype: int64
# low       1348
# medium       6
# high         1
# Name: exec_skips, dtype: int64

# %% [markdown]
# Again, we decide to have **two bins** for each quantitative variable

# %%
# create a copy of the dataframe that we will turn into categorical data
no_md_cat_df = no_md_df.copy()

# %%
# for each quantitative field in the data
for quant_var in no_md_quant_vars:
    
    # change the column in the dataframe so that it is binned into low, medium, and high
    no_md_cat_df.loc[:, quant_var] = pd.cut(no_md_cat_df[quant_var], 2, labels = labels)

# %%
# initial look at the new categorical data
no_md_cat_df.head()
# Out:
#    has_author jupyter_prop num_contrib image_prop  is_education  has_comments  \
# 0       False       higher       lower      lower         False         False
# 1       False       higher       lower      lower         False          True
# 2       False        lower       lower      lower         False          True
# 3       False       higher       lower      lower         False          True
# 4       False       higher       lower      lower         False          True
#
#   num_commits non_exec_prop exec_inorder exec_skips  has_error
# 0       lower         lower       higher      lower      False
# 1       lower         lower       higher      lower       True
# 2       lower         lower       higher      lower      False
# 3       lower         lower       higher      lower      False
# 4       lower         lower       higher      lower       True

# %%
# check the bin sizes again
for quant_var in no_md_quant_vars:
    print(no_md_cat_df[quant_var].value_counts())
# Out:
# higher    1263
# lower       92
# Name: jupyter_prop, dtype: int64
# lower     1348
# higher       7
# Name: num_contrib, dtype: int64
# lower     1102
# higher     253
# Name: image_prop, dtype: int64
# lower     1354
# higher       1
# Name: num_commits, dtype: int64
# lower     1249
# higher     106
# Name: non_exec_prop, dtype: int64
# higher    1290
# lower       65
# Name: exec_inorder, dtype: int64
# lower     1354
# higher       1
# Name: exec_skips, dtype: int64

# %% [markdown]
# # Multiple Correspondence Analysis (MCA)

# %% [markdown]
# # Association Rule Mining

# %% [markdown]
# ## One-Hot Encoding
#
# We must put our categorical data into a format that can be input into the Apriori algorithm

# %% [markdown]
# # To-Do
#
# <input type="checkbox"> Look at the outliers that are being placed by themselves in a bin
#
# <input type="checkbox"> Determine whether you want to keep 2 or 3 bins for the quantitative variables
#
# <input type="checkbox"> MCA
#
# <input type="checkbox"> one-hot encoding
#
# <input type="checkbox"> plug into apriori algorithm to get frequent itemsets
#
# <input type="checkbox"> analyze association rules from frequent itemsets
